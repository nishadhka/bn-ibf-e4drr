# %% [markdown]
# # Bnet creation
#
# In this notebook, we create a toy drought trigger bnet using pyagrum and
# supporting code of our own

# %%
# this makes sure it starts looking for things from the scumpy folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\bn-ibf-e4drr

# %%
from bnet import *

# %%
path = "data/leaf-nodes.csv"
ins_costs = [3, 4, 3]
rep_costs = [6, 12, 5]
build_bnet(path, ins_costs, rep_costs)
# Out:
# xxcf [2, 2, 2, 4]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 ins_costs = [3, 4, 3]
#       3 rep_costs = [6, 12, 5]
# ----> 4 build_bnet(path, ins_costs, rep_costs)
#
# File ~\Desktop\backed-up\python-projects\bn-ibf-e4drr\bnet.py:69, in build_bnet(csv_file, ins_costs, rep_costs)
#      66 bn.cpt("TriggerDecision")[:]= td_cpt
#      68 df = pd.read_csv(csv_file)
# ---> 69 learn_cpts_from_df(bn, df, ["FAR", "HR", "AUROC"])
#      71 return bn
#
# File ~\Desktop\backed-up\python-projects\bn-ibf-e4drr\cpt_from_df.py:53, in learn_cpts_from_df(bn, df, nd_names)
#      51 for name in nd_names:
#      52     if name in bn.names():
# ---> 53         learn_cpt_from_df(bn, df, name)
#
# File ~\Desktop\backed-up\python-projects\bn-ibf-e4drr\cpt_from_df.py:32, in learn_cpt_from_df(bn, df, nd_name)
#      29 else:
#      30     s = df[nd_name].value_counts(normalize=True)
# ---> 32 bn.cpt(id)[:] = np.array((s).transpose()).reshape(*domains)
#
# ValueError: cannot reshape array of size 50 into shape (2,4)
